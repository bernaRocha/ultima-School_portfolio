# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('data/dados_tratados.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4501 entries, 0 to 4500
# Data columns (total 31 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Q1                                     4501 non-null   float64
#  1   Q2                                     4501 non-null   float64
#  2   Q3                                     4501 non-null   float64
#  3   Q4                                     4501 non-null   float64
#  4   Q5                                     4501 non-null   float64
#  5   Q6                                     4501 non-null   float64
#  6   Q7                                     4501 non-null   float64
#  7   Q8                                     4501 non-null   float64
#  8   Q9                                     4501 non-null   float64
#  9   genero                                 4501 non-null   object
# ...

# %% [markdown]
# ## Diferenças de gênero nas 9 questões sobre humor
#
# Nas últimas 2 semanas, com que frequência você ficou incomodado por algum dos problemas a seguir: <br>
# 0 = Nenhuma vez <br>
# 1 = Menos de uma semana <br>
# 2 = Uma semana ou mais <br>
# 3 = Quase todos os dias <br>
# 7 = Se recusou a responder <br>
# 9 = Não sabe <br>

# %%
print('Pouco interesse ou pouco prazer em fazer as coisas ')
sns.countplot(data=df, 
              x=df["genero"], 
              width=0.7, 
              hue="Q1",
              saturation=0.7);
# Out:
# Pouco interesse ou pouco prazer em fazer as coisas

# %%
print('Se sentiu para baixo, deprimido(a) ou sem perspectiva')
sns.countplot(data=df, 
              x=df["genero"], 
              width=0.7, 
              hue="Q2",
              saturation=0.7);
# Out:
# Se sentiu para baixo, deprimido(a) ou sem perspectiva

# %%
print('Dificuldade para pegar no sono ou permanecer dormindo ou dormiu mais do que o costume')
sns.countplot(data=df, 
              x=df["genero"], 
              width=0.7, 
              hue="Q3",
              saturation=0.7);
# Out:
# Dificuldade para pegar no sono ou permanecer dormindo ou dormiu mais do que o costume

# %%
print('Se sentiu cansado(a) ou com pouca energia')
sns.countplot(data=df, 
              x=df["genero"], 
              width=0.7, 
              hue="Q4",
              saturation=0.7);
# Out:
# Se sentiu cansado(a) ou com pouca energia

# %%
print('Falta de apetite ou comeu demais')
sns.countplot(data=df, 
              x=df["genero"], 
              width=0.7, 
              hue="Q5",
              saturation=0.7);
# Out:
# Falta de apetite ou comeu demais

# %%
print('Se sentiu mal consigo mesmo(a) ou achou que é um fracasso ou que decepcionou sua família ou a você mesmo(a)')
sns.countplot(data=df, 
              x=df["genero"], 
              width=0.7, 
              hue="Q6",
              saturation=0.7);
# Out:
# Se sentiu mal consigo mesmo(a) ou achou que é um fracasso ou que decepcionou sua família ou a você mesmo(a)

# %%
print('Dificuldade para se concentrar nas coisas (como ler o jornal ou ver televisão)')
sns.countplot(data=df, 
              x=df["genero"], 
              width=0.7, 
              hue="Q7",
              saturation=0.7);
# Out:
# Dificuldade para se concentrar nas coisas (como ler o jornal ou ver televisão)

# %%
print('Teve lentidão para se movimentar ou falar (a ponto de outras pessoas perceberem), ou ao contrário, \nesteve tão agitado(a) que você ficava andando de um lado para o outro mais do que costume')
sns.countplot(data=df, 
              x=df["genero"], 
              width=0.7, 
              hue="Q8",
              saturation=0.7);
# Out:
# Teve lentidão para se movimentar ou falar (a ponto de outras pessoas perceberem), ou ao contrário,
# esteve tão agitado(a) que você ficava andando de um lado para o outro mais do que costume

# %%
print('Pensou em se ferir de alguma maneira ou que seria melhor estar morto(a)')
sns.countplot(data=df, 
              x=df["genero"], 
              width=0.7, 
              hue="Q9",
              saturation=0.7);
# Out:
# Pensou em se ferir de alguma maneira ou que seria melhor estar morto(a)

# %% [markdown]
# ## Outras diferenças a partir do gênero

# %%
sns.countplot(data=df, 
              y=df["escolaridade"], 
              width=0.6, 
              hue="genero",
              saturation=0.6, dodge=True);

# %%
sns.countplot(data=df, 
              x=df["renda_anual_familiar"], 
              width=0.6, 
              hue="genero",
              saturation=0.7, dodge=True);

# %%
sns.jointplot(data=df, x="score_saude", y="renda_anual_familiar", hue="genero")

# %%
sns.jointplot(data=df, y="renda_anual_familiar", x="score_saude", kind="hex");

# %% [markdown]
# ### Correlações

# %%
df['score_saude'].corr(df['renda_anual_familiar']).round(4)
# Out:
# 0.1011

# %%
df['total_vegetais'].corr(df['score_saude']).round(4)
# Out:
# 0.4053

# %%
df['total_verdura-v-escura-leguminosas'].corr(df['score_saude']).round(4)
# Out:
# 0.4601

# %%
df['total_frutas'].corr(df['score_saude']).round(4)
# Out:
# 0.5743

# %%
df['total_frutas_in-natura'].corr(df['score_saude']).round(4)
# Out:
# 0.5695

# %%
df['total_graos-integrais'].corr(df['score_saude']).round(4)
# Out:
# 0.4405

# %%
df['total_laticinios'].corr(df['score_saude']).round(4)
# Out:
# -0.0199

# %%
df['total_proteinas'].corr(df['score_saude']).round(4)
# Out:
# 0.2403

# %%
df['total_planta-marinha-proteina-vegetal'].corr(df['score_saude']).round(4)
# Out:
# 0.5042

# %%
df['total_acido-graxo'].corr(df['score_saude']).round(4)
# Out:
# 0.4687

# %%
df['total_sodio'].corr(df['score_saude']).round(4)
# Out:
# 0.2521

# %%
df['total_graos-refinados'].corr(df['score_saude']).round(4)
# Out:
# 0.357

# %%
df['total_gordura-saturada'].corr(df['score_saude']).round(4)
# Out:
# 0.4541

# %%
df['total_acucar-adicionado'].corr(df['score_saude']).round(4)
# Out:
# 0.3676
